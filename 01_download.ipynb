# %% [markdown]
# # 01 数据下载
#
# 本 Notebook 完成项目目录创建和四类数据获取：个股行情、市场指数、宏观指标、财务指标。具体下载函数集中在 `scripts/download_data.py`，优先使用 `akshare` 东方财富接口，失败时自动切换到新浪接口；只有两个真实接口都失败时才使用明确标记的 fallback。

# %% [markdown]
# ## 股票池与数据来源
#
# 股票池覆盖银行、白酒、汽车、能源、通讯五个行业。股票行情使用后复权日度数据，市场指数包括沪深 300 和中证 500，宏观指标包括 CPI 与 M2，财务指标包括 ROE 和资产负债率。

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
print(ROOT)
# Out:
# D:\自动海报生成器\dshw-p01

# %%
# %run scripts/download_data.py
# Out:
# [2026-05-18 13:51:24] SUCCESS stock_000001       shape=(1541, 10)
# [2026-05-18 13:51:25] SUCCESS stock_600036       shape=(1541, 10)
# [2026-05-18 13:51:26] SUCCESS stock_600519       shape=(1541, 10)
# [2026-05-18 13:51:27] SUCCESS stock_000858       shape=(1541, 10)
# [2026-05-18 13:51:28] SUCCESS stock_002594       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:29] SUCCESS stock_601633       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:30] SUCCESS stock_601857       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:31] SUCCESS stock_600900       shape=(1529, 10); provider=sina
# [2026-05-18 13:51:33] SUCCESS stock_600941       shape=(1053, 10); provider=sina
# [2026-05-18 13:51:34] SUCCESS stock_000063       shape=(1539, 10); provider=sina
# [2026-05-18 13:51:35] SUCCESS index_000300       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:36] SUCCESS index_000905       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:41] SUCCESS macro_cpi          shape=(68, 4)
# [2026-05-18 13:51:45] SUCCESS macro_m2           shape=(74, 4)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:51:47] SUCCESS finance_000001     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:51:50] SUCCESS finance_600036     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:51:52] SUCCESS finance_600519     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:51:55] SUCCESS finance_000858     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:51:57] SUCCESS finance_002594     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:52:00] SUCCESS finance_601633     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:52:03] SUCCESS finance_601857     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:52:06] SUCCESS finance_600900     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:52:08] SUCCESS finance_600941     shape=(10, 7)
#   0%|          | 0/7 [00:00<?, ?it/s]
# [2026-05-18 13:52:11] SUCCESS finance_000063     shape=(10, 7)

# %% [markdown]
# ## 下载结果检查
#
# 下面检查日志、原始数据文件数量和数据源分布。正式提交时应尽量看到 `SUCCESS`，且 `source` 应为 `akshare` 或 `akshare_sina`。

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
print((ROOT / "download_log.txt").read_text(encoding="utf-8"))

source_summary = {
    "stock": pd.concat([pd.read_csv(p, usecols=["source"]) for p in (ROOT / "data/stock").glob("stock_*.csv")])["source"].value_counts().to_dict(),
    "index": pd.concat([pd.read_csv(p, usecols=["source"]) for p in (ROOT / "data/index").glob("index_*.csv")])["source"].value_counts().to_dict(),
    "macro": pd.concat([pd.read_csv(p, usecols=["source"]) for p in (ROOT / "data/macro").glob("macro_*.csv")])["source"].value_counts().to_dict(),
    "finance": pd.read_csv(ROOT / "data/finance/finance_ratios.csv")["source"].value_counts().to_dict(),
}
source_summary
# Out:
# [2026-05-18 13:51:24] SUCCESS stock_000001       shape=(1541, 10)
# [2026-05-18 13:51:25] SUCCESS stock_600036       shape=(1541, 10)
# [2026-05-18 13:51:26] SUCCESS stock_600519       shape=(1541, 10)
# [2026-05-18 13:51:27] SUCCESS stock_000858       shape=(1541, 10)
# [2026-05-18 13:51:28] SUCCESS stock_002594       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:29] SUCCESS stock_601633       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:30] SUCCESS stock_601857       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:31] SUCCESS stock_600900       shape=(1529, 10); provider=sina
# [2026-05-18 13:51:33] SUCCESS stock_600941       shape=(1053, 10); provider=sina
# [2026-05-18 13:51:34] SUCCESS stock_000063       shape=(1539, 10); provider=sina
# [2026-05-18 13:51:35] SUCCESS index_000300       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:36] SUCCESS index_000905       shape=(1540, 10); provider=sina
# [2026-05-18 13:51:41] SUCCESS macro_cpi          shape=(68, 4)
# [2026-05-18 13:51:45] SUCCESS macro_m2           shape=(74, 4)
# [2026-05-18 13:51:47] SUCCESS finance_000001     shape=(10, 7)
# [2026-05-18 13:51:50] SUCCESS finance_600036     shape=(10, 7)
# [2026-05-18 13:51:52] SUCCESS finance_600519     shape=(10, 7)
# [2026-05-18 13:51:55] SUCCESS finance_000858     shape=(10, 7)
# [2026-05-18 13:51:57] SUCCESS finance_002594     shape=(10, 7)
# [2026-05-18 13:52:00] SUCCESS finance_601633     shape=(10, 7)
# [2026-05-18 13:52:03] SUCCESS finance_601857     shape=(10, 7)
# [2026-05-18 13:52:06] SUCCESS finance_600900     shape=(10, 7)
# [2026-05-18 13:52:08] SUCCESS finance_600941     shape=(10, 7)
# [2026-05-18 13:52:11] SUCCESS finance_000063     shape=(10, 7)
# {'stock': {'akshare_sina': 8741, 'akshare': 6164},
#  'index': {'akshare_sina': 3080},
#  'macro': {'akshare': 142},
#  'finance': {'akshare': 100}}
